# %% [markdown]
# # M.Amintoosi
#
# Read an image

# %%
from PIL import Image
img = Image.open(fileName).convert('LA')
imgplot = plt.imshow(img)
plt.show()
# np.savetxt('cat01_with_space.txt',cat,fmt='%03d', delimiter=' ')
img.save('cat01gray.png')

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

fileName = 'D:/DTemp/git/mamintoosi-cs.github.io/slides/topics/DL-HSU-Fall2019/images/cat.1.jpg'
img=mpimg.imread(fileName)
imgplot = plt.imshow(img)
plt.show()

# %%
print(type(img))
print(img.shape)
# Out:
# <class 'numpy.ndarray'>
# (140, 150, 3)

# %%
import numpy as np
np.set_printoptions(threshold=np.inf)
img[:,:,0]

# %%
cat = img[:,:,0]
np.savetxt('cat01.txt',cat,fmt='%3d')
# to_print = "\n".join([", ".join(str(row)) for row in cat])
# print (to_print) #console

# f = open("path-to-file", "w")
# f.write(to_print) #to file
